# %% [markdown]
# Preprocessing: Removing pixels with grayscalse intensity $<250$
# Model: 4 layers CNN
# Implementation of early stopping
# # New: Tuning of learning rate

# %%
#IMPORT LIBRARIES
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
import time
import datetime as dt
import progressbar

import pickle as pkl
import torch
from __future__ import print_function
import argparse
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
#from pytorchtools import EarlyStopping
#import torchvision
#import torchvision.transforms
from torch.autograd import Variable
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import torch.utils.data as data_utils
# Out:
# /home/perreaultlafleur/anaconda3/lib/python3.5/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)
# Using TensorFlow backend.

# %%
#IMPORT DATA
train_images = pd.read_pickle('train_max_x')
train_answers = pd.read_csv('train_max_y.csv')
test_images = pd.read_pickle('test_max_x')

#Define training, testing and validation datasets
X_train = train_images[0:45000]; X_test=train_images[45000:50000]; X_valid=test_images
y_train = train_answers.loc[0:44999,'Label']; y_test = train_answers.loc[45000:49999,'Label']

#Take out the funky backgrounds
X_train = (X_train>=250).astype(float)*255
X_test = (X_test>=250).astype(float)*255
X_valid = (X_valid>=250).astype(float)*255

#Add one dimension so that it can be an input for the NN
X_train = X_train.reshape(45000, 1, 128, 128)
X_test = X_test.reshape(5000, 1, 128, 128)
X_valid = X_valid.reshape(10000, 1, 128, 128)

#Change the type from numpy to tensor so that it can be an input for the NN
X_train = torch.from_numpy(X_train)
X_test = torch.from_numpy(X_test)
X_valid = torch.from_numpy(X_valid)

#do the same for the target vectors
y_train = torch.from_numpy(y_train.to_numpy().reshape(45000))
y_test = torch.from_numpy(y_test.to_numpy().reshape(5000))

#join the x and y values
train = data_utils.TensorDataset(X_train, y_train)
test = data_utils.TensorDataset(X_test, y_test)
valid = data_utils.TensorDataset(X_valid)

#create an iterator that will split the data in batches for training
trainloader = torch.utils.data.DataLoader(train, batch_size=256)
testloader = torch.utils.data.DataLoader(test, batch_size=256)
validloader = torch.utils.data.DataLoader(X_valid, batch_size=256)

# %%
class Classifier(nn.Module):
    """Convnet Classifier"""
    def __init__(self):
        super(Classifier, self).__init__()
        self.conv = nn.Sequential(
            # Layer 1
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=(3, 3), padding=1),
            nn.Dropout(p=0.5),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=2),
            
            # Layer 2
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=(3, 3), padding=1),
            nn.Dropout(p=0.5),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=2),
            
            # Layer 3
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(3, 3), padding=1),
            nn.Dropout(p=0.5),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=2),
            
            # Layer 4
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3, 3), padding=1),
            nn.Dropout(p=0.5),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 2), stride=2)
        )
        # Logistic Regression
        self.clf = nn.Linear(8192, 10)

    def forward(self, x):
        #print(self.conv(x).squeeze().reshape(64,-1).shape)
        out = self.conv(x)
        return self.clf(out.reshape(out.size(0), -1))
        #return self.clf(self.conv(x))

# %%
lr_valid_acc=[]
lr_train_loss=[]
lr_valid_loss=[]

for lr in np.arange(0.0001,0.00016,0.000025):

    clf = Classifier()
    optimizer = torch.optim.Adam(clf.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    epochs=80
    time1=dt.datetime.now()

    #Will print the plots
    avg_train_losses = []
    avg_valid_losses = []
    valid_acc = []
    index_of_best = 0

    #Early stopping criterion: when the test accuracy does not improve by at least #epsilon for #patience epochs in a row, we stop
    patience = 5
    epsilon = 0.1
    patience_iterator = 0
    best_test_acc = 0
    last_acc = 0
    stop = False

    #Training for loop
    for epoch in range(epochs):
        losses = []
        # Train
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            optimizer.zero_grad()
            inputs, targets = Variable(inputs), Variable(targets)
            outputs = clf(inputs.float())
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            losses.append(loss.data)
            #print('|', end ="")

        avg_train_losses.append(np.mean(losses))
        print('\nEpoch : %d Loss : %.3f ' % (epoch, np.mean(losses)))

        # Evaluate
        clf.eval()
        total = 0
        correct = 0
        losses = []
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = Variable(inputs), Variable(targets)
            outputs = clf(inputs.float())
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += predicted.eq(targets.data).cpu().sum()
            loss = criterion(outputs, targets)
            losses.append(loss.data)

        avg_valid_losses.append(np.mean(losses))
        test_acc = 100.*correct/total
        valid_acc.append(test_acc)
        print('Epoch : %d Test Acc : %.3f' % (epoch, test_acc))
        print('Epoch : %d Test Loss : %.3f ' % (epoch, np.mean(losses)))

        if test_acc > best_test_acc and not(stop):
            print('UPDATE: NEW BEST MODEL')
            filename = 'best_model_4_lr_%f.mdl' %lr
            torch.save(clf.state_dict(), filename)
            best_test_acc = test_acc
            index_of_best = epoch
        if test_acc <= last_acc + epsilon:
            patience_iterator = patience_iterator + 1
            print('Iterator for early stopping now at '+str(patience_iterator)+' since improvement of test accuracy = '+str((test_acc-last_acc).item())+' <= '+str(epsilon))
        else:
            patience_iterator = 0
            print('Iterator for early stopping reset to 0 since improvement of test accuracy = '+str((test_acc-last_acc).item())+' > '+str(epsilon))
        if patience_iterator == patience :
            stop = True
            print('Early stopping')

        print('----------------------------------------------------------------------------------------------------------------------------')
        last_acc = test_acc
        clf.train()

    #Training time
    time2=dt.datetime.now()
    print('Training time for '+str(epoch)+' epochs: '+str(time2-time1))
    
    # visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    plt.plot(range(1,len(avg_train_losses)+1),avg_train_losses, label='Training Loss')
    plt.plot(range(1,len(avg_valid_losses)+1),avg_valid_losses,label='Validation Loss')

    # find position of lowest validation loss
    minposs = index_of_best+1 
    plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0, 3.25) # consistent scale
    plt.xlim(0, len(avg_train_losses)+1) # consistent scale
    plt.title('Evolutions of the Training and Validation Cross-Entropy losses, and chosen model using Early Stopping')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # visualize the loss as the network trained
    fig = plt.figure(figsize=(10,8))
    #plt.plot(range(1,len(avg_train_losses)+1),valid_acc, label='Training Loss')
    plt.plot(range(1,len(valid_acc)+1),valid_acc,label='Validation Accuracy')

    # find position of lowest validation loss
    minposs = index_of_best+1
    plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim(0, 100) # consistent scale
    plt.xlim(0, len(avg_train_losses)+1) # consistent scale
    plt.title('Evolutions of the Training and Validation accuracies, and chosen model using Early Stopping ')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    lr_valid_acc.append(valid_acc)
    lr_train_loss.append(avg_train_losses)
    lr_valid_loss.append(avg_valid_losses)
# Out:
# Epoch : 0 Loss : 6.117
# Epoch : 0 Test Acc : 19.420
# Epoch : 0 Test Loss : 2.209
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 19.420000076293945 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 1 Loss : 2.202
# Epoch : 1 Test Acc : 23.100
# Epoch : 1 Test Loss : 2.232
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 3.6800003051757812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 2 Loss : 2.001
# Epoch : 2 Test Acc : 25.100
# Epoch : 2 Test Loss : 2.229
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.0 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 3 Loss : 1.956
# Epoch : 3 Test Acc : 25.220
# Epoch : 3 Test Loss : 2.221
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.11999893188476562 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 4 Loss : 1.936
# Epoch : 4 Test Acc : 24.880
# Epoch : 4 Test Loss : 2.212
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.3400001525878906 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 5 Loss : 1.925
# Epoch : 5 Test Acc : 25.800
# Epoch : 5 Test Loss : 2.202
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.9200000762939453 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 6 Loss : 1.911
# Epoch : 6 Test Acc : 26.440
# Epoch : 6 Test Loss : 2.190
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6400012969970703 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 7 Loss : 1.902
# Epoch : 7 Test Acc : 26.940
# Epoch : 7 Test Loss : 2.176
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 8 Loss : 1.897
# Epoch : 8 Test Acc : 26.960
# Epoch : 8 Test Loss : 2.166
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.019998550415039062 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 9 Loss : 1.893
# Epoch : 9 Test Acc : 27.340
# Epoch : 9 Test Loss : 2.157
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.3800010681152344 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 10 Loss : 1.890
# Epoch : 10 Test Acc : 27.160
# Epoch : 10 Test Loss : 2.149
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.18000030517578125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 11 Loss : 1.887
# Epoch : 11 Test Acc : 27.300
# Epoch : 11 Test Loss : 2.141
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 12 Loss : 1.883
# Epoch : 12 Test Acc : 27.360
# Epoch : 12 Test Loss : 2.135
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.060001373291015625 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 13 Loss : 1.879
# Epoch : 13 Test Acc : 27.780
# Epoch : 13 Test Loss : 2.130
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.4200000762939453 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 14 Loss : 1.874
# Epoch : 14 Test Acc : 28.140
# Epoch : 14 Test Loss : 2.120
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.3599987030029297 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 15 Loss : 1.864
# Epoch : 15 Test Acc : 29.320
# Epoch : 15 Test Loss : 2.109
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1800003051757812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 16 Loss : 1.854
# Epoch : 16 Test Acc : 29.460
# Epoch : 16 Test Loss : 2.097
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 17 Loss : 1.836
# Epoch : 17 Test Acc : 30.780
# Epoch : 17 Test Loss : 2.085
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.3200016021728516 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 18 Loss : 1.821
# Epoch : 18 Test Acc : 33.360
# Epoch : 18 Test Loss : 2.074
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.5799999237060547 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 19 Loss : 1.804
# Epoch : 19 Test Acc : 34.900
# Epoch : 19 Test Loss : 2.057
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.5400009155273438 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 20 Loss : 1.784
# Epoch : 20 Test Acc : 35.280
# Epoch : 20 Test Loss : 2.039
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.37999725341796875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 21 Loss : 1.764
# Epoch : 21 Test Acc : 37.480
# Epoch : 21 Test Loss : 2.023
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.200000762939453 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 22 Loss : 1.743
# Epoch : 22 Test Acc : 39.120
# Epoch : 22 Test Loss : 1.993
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.6399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 23 Loss : 1.719
# Epoch : 23 Test Acc : 40.220
# Epoch : 23 Test Loss : 1.971
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1000022888183594 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 24 Loss : 1.697
# Epoch : 24 Test Acc : 42.120
# Epoch : 24 Test Loss : 1.941
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.8999977111816406 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 25 Loss : 1.671
# Epoch : 25 Test Acc : 42.420
# Epoch : 25 Test Loss : 1.911
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.2999992370605469 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 26 Loss : 1.641
# Epoch : 26 Test Acc : 43.380
# Epoch : 26 Test Loss : 1.876
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.9600028991699219 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 27 Loss : 1.612
# Epoch : 27 Test Acc : 45.100
# Epoch : 27 Test Loss : 1.853
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.7199974060058594 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 28 Loss : 1.579
# Epoch : 28 Test Acc : 47.420
# Epoch : 28 Test Loss : 1.831
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.3199996948242188 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 29 Loss : 1.544
# Epoch : 29 Test Acc : 50.360
# Epoch : 29 Test Loss : 1.815
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.94000244140625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 30 Loss : 1.518
# Epoch : 30 Test Acc : 52.420
# Epoch : 30 Test Loss : 1.789
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.05999755859375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 31 Loss : 1.484
# Epoch : 31 Test Acc : 52.880
# Epoch : 31 Test Loss : 1.755
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.4600028991699219 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 32 Loss : 1.447
# Epoch : 32 Test Acc : 57.020
# Epoch : 32 Test Loss : 1.740
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 4.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 33 Loss : 1.409
# Epoch : 33 Test Acc : 58.520
# Epoch : 33 Test Loss : 1.707
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 34 Loss : 1.374
# Epoch : 34 Test Acc : 59.780
# Epoch : 34 Test Loss : 1.669
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.2599983215332031 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 35 Loss : 1.329
# Epoch : 35 Test Acc : 62.340
# Epoch : 35 Test Loss : 1.638
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.5600013732910156 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 36 Loss : 1.298
# Epoch : 36 Test Acc : 63.940
# Epoch : 36 Test Loss : 1.604
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.5999984741210938 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 37 Loss : 1.263
# Epoch : 37 Test Acc : 64.700
# Epoch : 37 Test Loss : 1.576
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.7599983215332031 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 38 Loss : 1.231
# Epoch : 38 Test Acc : 66.960
# Epoch : 38 Test Loss : 1.549
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.2600021362304688 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 39 Loss : 1.207
# Epoch : 39 Test Acc : 67.120
# Epoch : 39 Test Loss : 1.505
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.160003662109375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 40 Loss : 1.187
# Epoch : 40 Test Acc : 68.640
# Epoch : 40 Test Loss : 1.495
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.5199966430664062 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 41 Loss : 1.150
# Epoch : 41 Test Acc : 70.400
# Epoch : 41 Test Loss : 1.466
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.7600021362304688 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 42 Loss : 1.125
# Epoch : 42 Test Acc : 71.240
# Epoch : 42 Test Loss : 1.440
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.839996337890625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 43 Loss : 1.105
# Epoch : 43 Test Acc : 72.400
# Epoch : 43 Test Loss : 1.419
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.160003662109375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 44 Loss : 1.081
# Epoch : 44 Test Acc : 72.720
# Epoch : 44 Test Loss : 1.395
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.31999969482421875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 45 Loss : 1.054
# Epoch : 45 Test Acc : 73.840
# Epoch : 45 Test Loss : 1.375
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1199951171875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 46 Loss : 1.038
# Epoch : 46 Test Acc : 74.260
# Epoch : 46 Test Loss : 1.342
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.42000579833984375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 47 Loss : 1.014
# Epoch : 47 Test Acc : 75.480
# Epoch : 47 Test Loss : 1.325
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.220001220703125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 48 Loss : 0.993
# Epoch : 48 Test Acc : 76.720
# Epoch : 48 Test Loss : 1.305
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.2399978637695312 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 49 Loss : 0.969
# Epoch : 49 Test Acc : 76.800
# Epoch : 49 Test Loss : 1.279
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.0800018310546875 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 50 Loss : 0.953
# Epoch : 50 Test Acc : 77.920
# Epoch : 50 Test Loss : 1.248
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1199951171875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 51 Loss : 0.930
# Epoch : 51 Test Acc : 78.840
# Epoch : 51 Test Loss : 1.236
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.9199981689453125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 52 Loss : 0.914
# Epoch : 52 Test Acc : 79.660
# Epoch : 52 Test Loss : 1.231
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.82000732421875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 53 Loss : 0.888
# Epoch : 53 Test Acc : 79.740
# Epoch : 53 Test Loss : 1.195
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.07999420166015625 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 54 Loss : 0.879
# Epoch : 54 Test Acc : 80.460
# Epoch : 54 Test Loss : 1.178
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.720001220703125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 55 Loss : 0.859
# Epoch : 55 Test Acc : 80.560
# Epoch : 55 Test Loss : 1.167
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.09999847412109375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 56 Loss : 0.852
# Epoch : 56 Test Acc : 81.060
# Epoch : 56 Test Loss : 1.146
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 57 Loss : 0.832
# Epoch : 57 Test Acc : 81.720
# Epoch : 57 Test Loss : 1.126
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.660003662109375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 58 Loss : 0.819
# Epoch : 58 Test Acc : 81.520
# Epoch : 58 Test Loss : 1.113
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.20000457763671875 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 59 Loss : 0.803
# Epoch : 59 Test Acc : 82.200
# Epoch : 59 Test Loss : 1.100
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6800003051757812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 60 Loss : 0.785
# Epoch : 60 Test Acc : 82.580
# Epoch : 60 Test Loss : 1.080
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.3800048828125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 61 Loss : 0.775
# Epoch : 61 Test Acc : 83.020
# Epoch : 61 Test Loss : 1.079
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.43999481201171875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 62 Loss : 0.765
# Epoch : 62 Test Acc : 83.600
# Epoch : 62 Test Loss : 1.061
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5800018310546875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 63 Loss : 0.754
# Epoch : 63 Test Acc : 83.880
# Epoch : 63 Test Loss : 1.047
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.279998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 64 Loss : 0.742
# Epoch : 64 Test Acc : 84.060
# Epoch : 64 Test Loss : 1.035
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.18000030517578125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 65 Loss : 0.723
# Epoch : 65 Test Acc : 84.120
# Epoch : 65 Test Loss : 1.021
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.06000518798828125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 66 Loss : 0.720
# Epoch : 66 Test Acc : 84.460
# Epoch : 66 Test Loss : 1.021
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.339996337890625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 67 Loss : 0.710
# Epoch : 67 Test Acc : 84.240
# Epoch : 67 Test Loss : 1.001
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.220001220703125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 68 Loss : 0.702
# Epoch : 68 Test Acc : 84.560
# Epoch : 68 Test Loss : 0.988
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.31999969482421875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 69 Loss : 0.694
# Epoch : 69 Test Acc : 85.180
# Epoch : 69 Test Loss : 0.987
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6200027465820312 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 70 Loss : 0.681
# Epoch : 70 Test Acc : 85.340
# Epoch : 70 Test Loss : 0.966
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.15999603271484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 71 Loss : 0.672
# Epoch : 71 Test Acc : 85.880
# Epoch : 71 Test Loss : 0.977
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5400009155273438 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 72 Loss : 0.663
# Epoch : 72 Test Acc : 85.400
# Epoch : 72 Test Loss : 0.962
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.4799957275390625 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 73 Loss : 0.660
# Epoch : 73 Test Acc : 85.760
# Epoch : 73 Test Loss : 0.957
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.3600006103515625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 74 Loss : 0.644
# Epoch : 74 Test Acc : 85.820
# Epoch : 74 Test Loss : 0.935
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.05999755859375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 75 Loss : 0.635
# Epoch : 75 Test Acc : 85.600
# Epoch : 75 Test Loss : 0.926
# Iterator for early stopping now at 2 since improvement of test accuracy = -0.220001220703125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 76 Loss : 0.633
# Epoch : 76 Test Acc : 85.760
# Epoch : 76 Test Loss : 0.918
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.160003662109375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 77 Loss : 0.626
# Epoch : 77 Test Acc : 86.280
# Epoch : 77 Test Loss : 0.919
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5199966430664062 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 78 Loss : 0.619
# Epoch : 78 Test Acc : 85.980
# Epoch : 78 Test Loss : 0.912
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.29999542236328125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 79 Loss : 0.613
# Epoch : 79 Test Acc : 86.100
# Epoch : 79 Test Loss : 0.903
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1199951171875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
# Training time for 79 epochs: 5:31:04.912837
# Epoch : 0 Loss : 5.279
# Epoch : 0 Test Acc : 22.260
# Epoch : 0 Test Loss : 2.214
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 22.260000228881836 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 1 Loss : 2.093
# Epoch : 1 Test Acc : 24.360
# Epoch : 1 Test Loss : 2.233
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.1000003814697266 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 2 Loss : 1.963
# Epoch : 2 Test Acc : 25.320
# Epoch : 2 Test Loss : 2.206
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.9599990844726562 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 3 Loss : 1.922
# Epoch : 3 Test Acc : 26.460
# Epoch : 3 Test Loss : 2.174
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 4 Loss : 1.905
# Epoch : 4 Test Acc : 27.300
# Epoch : 4 Test Loss : 2.156
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.8400001525878906 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 5 Loss : 1.894
# Epoch : 5 Test Acc : 27.220
# Epoch : 5 Test Loss : 2.148
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.07999992370605469 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 6 Loss : 1.890
# Epoch : 6 Test Acc : 27.220
# Epoch : 6 Test Loss : 2.148
# Iterator for early stopping now at 2 since improvement of test accuracy = 0.0 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 7 Loss : 1.886
# Epoch : 7 Test Acc : 27.200
# Epoch : 7 Test Loss : 2.142
# Iterator for early stopping now at 3 since improvement of test accuracy = -0.019998550415039062 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 8 Loss : 1.885
# Epoch : 8 Test Acc : 27.240
# Epoch : 8 Test Loss : 2.139
# Iterator for early stopping now at 4 since improvement of test accuracy = 0.03999900817871094 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 9 Loss : 1.884
# Epoch : 9 Test Acc : 27.260
# Epoch : 9 Test Loss : 2.127
# Iterator for early stopping now at 5 since improvement of test accuracy = 0.020000457763671875 <= 0.1
# Early stopping
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 10 Loss : 1.882
# Epoch : 10 Test Acc : 27.200
# Epoch : 10 Test Loss : 2.116
# Iterator for early stopping now at 6 since improvement of test accuracy = -0.05999946594238281 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 11 Loss : 1.880
# Epoch : 11 Test Acc : 27.180
# Epoch : 11 Test Loss : 2.115
# Iterator for early stopping now at 7 since improvement of test accuracy = -0.020000457763671875 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 12 Loss : 1.879
# Epoch : 12 Test Acc : 27.060
# Epoch : 12 Test Loss : 2.106
# Iterator for early stopping now at 8 since improvement of test accuracy = -0.12000083923339844 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 13 Loss : 1.876
# Epoch : 13 Test Acc : 27.340
# Epoch : 13 Test Loss : 2.103
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.2800006866455078 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 14 Loss : 1.873
# Epoch : 14 Test Acc : 27.440
# Epoch : 14 Test Loss : 2.089
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.10000038146972656 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 15 Loss : 1.870
# Epoch : 15 Test Acc : 27.720
# Epoch : 15 Test Loss : 2.074
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.279998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 16 Loss : 1.861
# Epoch : 16 Test Acc : 28.280
# Epoch : 16 Test Loss : 2.053
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5600013732910156 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 17 Loss : 1.842
# Epoch : 17 Test Acc : 29.380
# Epoch : 17 Test Loss : 2.030
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.0999984741210938 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 18 Loss : 1.804
# Epoch : 18 Test Acc : 33.940
# Epoch : 18 Test Loss : 2.000
# Iterator for early stopping reset to 0 since improvement of test accuracy = 4.559999465942383 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 19 Loss : 1.770
# Epoch : 19 Test Acc : 35.800
# Epoch : 19 Test Loss : 1.971
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.8600006103515625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 20 Loss : 1.740
# Epoch : 20 Test Acc : 38.480
# Epoch : 20 Test Loss : 1.951
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.6800003051757812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 21 Loss : 1.711
# Epoch : 21 Test Acc : 40.960
# Epoch : 21 Test Loss : 1.927
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.479999542236328 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 22 Loss : 1.684
# Epoch : 22 Test Acc : 43.340
# Epoch : 22 Test Loss : 1.905
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.3800010681152344 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 23 Loss : 1.655
# Epoch : 23 Test Acc : 44.720
# Epoch : 23 Test Loss : 1.888
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.3800010681152344 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 24 Loss : 1.623
# Epoch : 24 Test Acc : 47.040
# Epoch : 24 Test Loss : 1.866
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.3199996948242188 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 25 Loss : 1.597
# Epoch : 25 Test Acc : 49.240
# Epoch : 25 Test Loss : 1.854
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.200000762939453 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 26 Loss : 1.571
# Epoch : 26 Test Acc : 49.680
# Epoch : 26 Test Loss : 1.823
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.4399986267089844 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 27 Loss : 1.537
# Epoch : 27 Test Acc : 52.200
# Epoch : 27 Test Loss : 1.801
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.520000457763672 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 28 Loss : 1.504
# Epoch : 28 Test Acc : 54.140
# Epoch : 28 Test Loss : 1.777
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.9399986267089844 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 29 Loss : 1.457
# Epoch : 29 Test Acc : 55.240
# Epoch : 29 Test Loss : 1.730
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1000022888183594 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 30 Loss : 1.417
# Epoch : 30 Test Acc : 59.000
# Epoch : 30 Test Loss : 1.702
# Iterator for early stopping reset to 0 since improvement of test accuracy = 3.759998321533203 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 31 Loss : 1.372
# Epoch : 31 Test Acc : 61.080
# Epoch : 31 Test Loss : 1.663
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.0800018310546875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 32 Loss : 1.321
# Epoch : 32 Test Acc : 63.440
# Epoch : 32 Test Loss : 1.609
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.359996795654297 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 33 Loss : 1.279
# Epoch : 33 Test Acc : 64.560
# Epoch : 33 Test Loss : 1.559
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1199989318847656 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 34 Loss : 1.239
# Epoch : 34 Test Acc : 67.220
# Epoch : 34 Test Loss : 1.541
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.660003662109375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 35 Loss : 1.193
# Epoch : 35 Test Acc : 68.640
# Epoch : 35 Test Loss : 1.508
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.4199981689453125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 36 Loss : 1.171
# Epoch : 36 Test Acc : 70.480
# Epoch : 36 Test Loss : 1.484
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.8400039672851562 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 37 Loss : 1.136
# Epoch : 37 Test Acc : 71.380
# Epoch : 37 Test Loss : 1.438
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.899993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 38 Loss : 1.101
# Epoch : 38 Test Acc : 72.180
# Epoch : 38 Test Loss : 1.398
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.8000030517578125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 39 Loss : 1.076
# Epoch : 39 Test Acc : 73.340
# Epoch : 39 Test Loss : 1.362
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1599960327148438 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 40 Loss : 1.042
# Epoch : 40 Test Acc : 74.880
# Epoch : 40 Test Loss : 1.340
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.5400009155273438 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 41 Loss : 1.015
# Epoch : 41 Test Acc : 74.860
# Epoch : 41 Test Loss : 1.287
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.01999664306640625 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 42 Loss : 0.989
# Epoch : 42 Test Acc : 75.960
# Epoch : 42 Test Loss : 1.266
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.0999984741210938 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 43 Loss : 0.963
# Epoch : 43 Test Acc : 77.800
# Epoch : 43 Test Loss : 1.256
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.8400039672851562 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 44 Loss : 0.933
# Epoch : 44 Test Acc : 78.300
# Epoch : 44 Test Loss : 1.207
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 45 Loss : 0.912
# Epoch : 45 Test Acc : 79.220
# Epoch : 45 Test Loss : 1.196
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.9199981689453125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 46 Loss : 0.893
# Epoch : 46 Test Acc : 79.720
# Epoch : 46 Test Loss : 1.176
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 47 Loss : 0.878
# Epoch : 47 Test Acc : 80.220
# Epoch : 47 Test Loss : 1.154
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 48 Loss : 0.854
# Epoch : 48 Test Acc : 81.100
# Epoch : 48 Test Loss : 1.127
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.8799972534179688 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 49 Loss : 0.844
# Epoch : 49 Test Acc : 81.240
# Epoch : 49 Test Loss : 1.112
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 50 Loss : 0.822
# Epoch : 50 Test Acc : 81.480
# Epoch : 50 Test Loss : 1.110
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.2400054931640625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 51 Loss : 0.809
# Epoch : 51 Test Acc : 81.900
# Epoch : 51 Test Loss : 1.086
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.4199981689453125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 52 Loss : 0.792
# Epoch : 52 Test Acc : 82.660
# Epoch : 52 Test Loss : 1.068
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.7600021362304688 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 53 Loss : 0.777
# Epoch : 53 Test Acc : 83.060
# Epoch : 53 Test Loss : 1.052
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 54 Loss : 0.767
# Epoch : 54 Test Acc : 83.200
# Epoch : 54 Test Loss : 1.056
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 55 Loss : 0.759
# Epoch : 55 Test Acc : 83.540
# Epoch : 55 Test Loss : 1.052
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.34000396728515625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 56 Loss : 0.743
# Epoch : 56 Test Acc : 84.180
# Epoch : 56 Test Loss : 1.024
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 57 Loss : 0.730
# Epoch : 57 Test Acc : 84.680
# Epoch : 57 Test Loss : 1.014
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 58 Loss : 0.719
# Epoch : 58 Test Acc : 84.620
# Epoch : 58 Test Loss : 0.990
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.05999755859375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 59 Loss : 0.710
# Epoch : 59 Test Acc : 84.920
# Epoch : 59 Test Loss : 0.993
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.29999542236328125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 60 Loss : 0.696
# Epoch : 60 Test Acc : 84.940
# Epoch : 60 Test Loss : 0.975
# Iterator for early stopping now at 1 since improvement of test accuracy = 0.0200042724609375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 61 Loss : 0.686
# Epoch : 61 Test Acc : 85.080
# Epoch : 61 Test Loss : 0.961
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 62 Loss : 0.677
# Epoch : 62 Test Acc : 85.800
# Epoch : 62 Test Loss : 0.965
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.720001220703125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 63 Loss : 0.674
# Epoch : 63 Test Acc : 85.580
# Epoch : 63 Test Loss : 0.961
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.220001220703125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 64 Loss : 0.660
# Epoch : 64 Test Acc : 85.920
# Epoch : 64 Test Loss : 0.938
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.339996337890625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 65 Loss : 0.658
# Epoch : 65 Test Acc : 86.200
# Epoch : 65 Test Loss : 0.933
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.279998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 66 Loss : 0.639
# Epoch : 66 Test Acc : 86.100
# Epoch : 66 Test Loss : 0.917
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.09999847412109375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 67 Loss : 0.632
# Epoch : 67 Test Acc : 86.220
# Epoch : 67 Test Loss : 0.923
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.12000274658203125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 68 Loss : 0.624
# Epoch : 68 Test Acc : 86.100
# Epoch : 68 Test Loss : 0.899
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.12000274658203125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 69 Loss : 0.625
# Epoch : 69 Test Acc : 87.080
# Epoch : 69 Test Loss : 0.909
# ...
#
# Epoch : 31 Loss : 1.133
# Epoch : 31 Test Acc : 68.600
# Epoch : 31 Test Loss : 1.366
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.839996337890625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 32 Loss : 1.089
# Epoch : 32 Test Acc : 70.080
# Epoch : 32 Test Loss : 1.341
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.4800033569335938 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 33 Loss : 1.052
# Epoch : 33 Test Acc : 71.240
# Epoch : 33 Test Loss : 1.299
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1599960327148438 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 34 Loss : 1.024
# Epoch : 34 Test Acc : 73.340
# Epoch : 34 Test Loss : 1.282
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 2.0999984741210938 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 35 Loss : 0.996
# Epoch : 35 Test Acc : 74.740
# Epoch : 35 Test Loss : 1.260
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.4000015258789062 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 36 Loss : 0.966
# Epoch : 36 Test Acc : 75.300
# Epoch : 36 Test Loss : 1.220
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5600051879882812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 37 Loss : 0.941
# Epoch : 37 Test Acc : 76.080
# Epoch : 37 Test Loss : 1.209
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.779998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 38 Loss : 0.916
# Epoch : 38 Test Acc : 77.860
# Epoch : 38 Test Loss : 1.189
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.779998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 39 Loss : 0.892
# Epoch : 39 Test Acc : 79.020
# Epoch : 39 Test Loss : 1.165
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.1599960327148438 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 40 Loss : 0.865
# Epoch : 40 Test Acc : 79.120
# Epoch : 40 Test Loss : 1.132
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.100006103515625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 41 Loss : 0.851
# Epoch : 41 Test Acc : 79.640
# Epoch : 41 Test Loss : 1.116
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5199966430664062 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 42 Loss : 0.828
# Epoch : 42 Test Acc : 80.640
# Epoch : 42 Test Loss : 1.089
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.0 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 43 Loss : 0.804
# Epoch : 43 Test Acc : 81.260
# Epoch : 43 Test Loss : 1.075
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6200027465820312 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 44 Loss : 0.785
# Epoch : 44 Test Acc : 82.160
# Epoch : 44 Test Loss : 1.061
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.9000015258789062 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 45 Loss : 0.776
# Epoch : 45 Test Acc : 82.300
# Epoch : 45 Test Loss : 1.044
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 46 Loss : 0.758
# Epoch : 46 Test Acc : 82.980
# Epoch : 46 Test Loss : 1.016
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6800003051757812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 47 Loss : 0.735
# Epoch : 47 Test Acc : 82.860
# Epoch : 47 Test Loss : 1.008
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.12000274658203125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 48 Loss : 0.733
# Epoch : 48 Test Acc : 83.640
# Epoch : 48 Test Loss : 0.998
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.779998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 49 Loss : 0.715
# Epoch : 49 Test Acc : 84.240
# Epoch : 49 Test Loss : 0.979
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.5999984741210938 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 50 Loss : 0.702
# Epoch : 50 Test Acc : 84.440
# Epoch : 50 Test Loss : 0.977
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.20000457763671875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 51 Loss : 0.686
# Epoch : 51 Test Acc : 84.200
# Epoch : 51 Test Loss : 0.948
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.2400054931640625 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 52 Loss : 0.670
# Epoch : 52 Test Acc : 84.960
# Epoch : 52 Test Loss : 0.938
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.7600021362304688 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 53 Loss : 0.664
# Epoch : 53 Test Acc : 84.580
# Epoch : 53 Test Loss : 0.918
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.37999725341796875 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 54 Loss : 0.654
# Epoch : 54 Test Acc : 85.980
# Epoch : 54 Test Loss : 0.928
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 1.4000015258789062 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 55 Loss : 0.646
# Epoch : 55 Test Acc : 85.840
# Epoch : 55 Test Loss : 0.915
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.14000701904296875 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 56 Loss : 0.628
# Epoch : 56 Test Acc : 86.280
# Epoch : 56 Test Loss : 0.904
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.44000244140625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 57 Loss : 0.622
# Epoch : 57 Test Acc : 86.480
# Epoch : 57 Test Loss : 0.885
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.20000457763671875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 58 Loss : 0.612
# Epoch : 58 Test Acc : 86.800
# Epoch : 58 Test Loss : 0.884
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.31999969482421875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 59 Loss : 0.612
# Epoch : 59 Test Acc : 86.520
# Epoch : 59 Test Loss : 0.890
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.28000640869140625 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 60 Loss : 0.599
# Epoch : 60 Test Acc : 86.620
# Epoch : 60 Test Loss : 0.869
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.100006103515625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 61 Loss : 0.593
# Epoch : 61 Test Acc : 87.020
# Epoch : 61 Test Loss : 0.862
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.399993896484375 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 62 Loss : 0.586
# Epoch : 62 Test Acc : 87.220
# Epoch : 62 Test Loss : 0.845
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.20000457763671875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 63 Loss : 0.579
# Epoch : 63 Test Acc : 87.440
# Epoch : 63 Test Loss : 0.847
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.220001220703125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 64 Loss : 0.564
# Epoch : 64 Test Acc : 87.260
# Epoch : 64 Test Loss : 0.846
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.18000030517578125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 65 Loss : 0.561
# Epoch : 65 Test Acc : 87.300
# Epoch : 65 Test Loss : 0.828
# Iterator for early stopping now at 2 since improvement of test accuracy = 0.04000091552734375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 66 Loss : 0.553
# Epoch : 66 Test Acc : 87.780
# Epoch : 66 Test Loss : 0.822
# UPDATE: NEW BEST MODEL
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.4799957275390625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 67 Loss : 0.549
# Epoch : 67 Test Acc : 87.640
# Epoch : 67 Test Loss : 0.821
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.1399993896484375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 68 Loss : 0.545
# Epoch : 68 Test Acc : 87.740
# Epoch : 68 Test Loss : 0.814
# Iterator for early stopping now at 2 since improvement of test accuracy = 0.09999847412109375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 69 Loss : 0.539
# Epoch : 69 Test Acc : 87.760
# Epoch : 69 Test Loss : 0.802
# Iterator for early stopping now at 3 since improvement of test accuracy = 0.0200042724609375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 70 Loss : 0.530
# Epoch : 70 Test Acc : 87.860
# Epoch : 70 Test Loss : 0.794
# UPDATE: NEW BEST MODEL
# Iterator for early stopping now at 4 since improvement of test accuracy = 0.09999847412109375 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 71 Loss : 0.526
# Epoch : 71 Test Acc : 87.820
# Epoch : 71 Test Loss : 0.793
# Iterator for early stopping now at 5 since improvement of test accuracy = -0.04000091552734375 <= 0.1
# Early stopping
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 72 Loss : 0.524
# Epoch : 72 Test Acc : 87.700
# Epoch : 72 Test Loss : 0.808
# Iterator for early stopping now at 6 since improvement of test accuracy = -0.12000274658203125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 73 Loss : 0.515
# Epoch : 73 Test Acc : 88.380
# Epoch : 73 Test Loss : 0.784
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.6800003051757812 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 74 Loss : 0.503
# Epoch : 74 Test Acc : 88.480
# Epoch : 74 Test Loss : 0.780
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.100006103515625 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 75 Loss : 0.507
# Epoch : 75 Test Acc : 88.400
# Epoch : 75 Test Loss : 0.775
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.0800018310546875 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 76 Loss : 0.501
# Epoch : 76 Test Acc : 88.520
# Epoch : 76 Test Loss : 0.776
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.1199951171875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 77 Loss : 0.491
# Epoch : 77 Test Acc : 88.220
# Epoch : 77 Test Loss : 0.756
# Iterator for early stopping now at 1 since improvement of test accuracy = -0.29999542236328125 <= 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 78 Loss : 0.488
# Epoch : 78 Test Acc : 88.500
# Epoch : 78 Test Loss : 0.759
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.279998779296875 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
#
# Epoch : 79 Loss : 0.487
# Epoch : 79 Test Acc : 88.680
# Epoch : 79 Test Loss : 0.760
# Iterator for early stopping reset to 0 since improvement of test accuracy = 0.18000030517578125 > 0.1
# ----------------------------------------------------------------------------------------------------------------------------
# Training time for 79 epochs: 5:33:28.267320

# %%
# visualize the loss as the network trained
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(avg_train_losses)+1),avg_train_losses, label='Training Loss')
plt.plot(range(1,len(avg_valid_losses)+1),avg_valid_losses,label='Validation Loss')

# find position of lowest validation loss
minposs = index_of_best+1  
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 3.25) # consistent scale
plt.xlim(0, len(avg_train_losses)+1) # consistent scale
plt.title('Evolutions of the Training and Validation Cross-Entropy losses, and chosen model using Early Stopping ')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# visualize the loss as the network trained
fig = plt.figure(figsize=(10,8))
#plt.plot(range(1,len(avg_train_losses)+1),valid_acc, label='Training Loss')
plt.plot(range(1,len(valid_acc)+1),valid_acc,label='Validation Accuracy')

# find position of lowest validation loss
minposs = index_of_best+1  
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 100) # consistent scale
plt.xlim(0, len(avg_train_losses)+1) # consistent scale
plt.title('Evolutions of the Training and Validation accuracies, and chosen model using Early Stopping ')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # MAKE REAL PREDICTIONS

# %%
#Later to restore the best model
# load the desired file ! 
clf.load_state_dict(torch.load('best_model.mdl'))
clf.eval()
# Out:
# Classifier(
#   (conv): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Dropout(p=0.5, inplace=False)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): Dropout(p=0.5, inplace=False)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): Dropout(p=0.5, inplace=False)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (clf): Linear(in_features=8192, out_features=10, bias=True)
# )

# %%
#Make the final predictions
pred = []
for batch_idx, inputs in enumerate(validloader):
    inputs = Variable(inputs)
    outputs = clf(inputs.float())
    _, predicted = torch.max(outputs.data, 1)
    pred.extend(predicted.tolist())
final_preds = pd.DataFrame()
final_preds['Id'] = list(range(0,10000))
final_preds['Label'] = pred
final_preds.to_csv('Prediction_3.csv', index=False)
